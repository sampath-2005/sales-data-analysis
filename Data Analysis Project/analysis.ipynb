# %%
import pandas as pd
df = pd.read_csv("train.csv")
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])
df = df.drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df['Order Date'] = pd.to_datetime(df['Order Date'])
#       2 df['Ship Date'] = pd.to_datetime(df['Ship Date'])
#       3 df = df.drop_duplicates()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1068, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1066             result = arg.tz_localize("utc")
#    1067 elif isinstance(arg, ABCSeries):
# -> 1068     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1069     if not cache_array.empty:
#    1070         result = arg.map(cache_array)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:249, in _maybe_cache(arg, format, cache, convert_listlike)
#     247 unique_dates = unique(arg)
#     248 if len(unique_dates) < len(arg):
# ...

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], dayfirst=True, errors='coerce')
df['Ship Date'] = pd.to_datetime(df['Ship Date'], dayfirst=True, errors='coerce')

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %%
df['Month'] = df['Order Date'].dt.to_period('M')

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 2       3  CA-2017-138688 2017-06-12 2017-06-16    Second Class    DV-13045
# 3       4  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
# 4       5  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df['Month'] = df['Order Date'].dt.to_period('M')

# %%
cat_sales = df.groupby("Category")["Sales"].sum().sort_values(ascending=False)
subcat_sales = df.groupby("Sub-Category")["Sales"].sum().sort_values(ascending=False)
print(cat_sales)
print(subcat_sales.head(10))
# Out:
# Category
# Technology         827455.8730
# Furniture          728658.5757
# Office Supplies    705422.3340
# Name: Sales, dtype: float64
# Sub-Category
# Phones         327782.4480
# Chairs         322822.7310
# Storage        219343.3920
# Tables         202810.6280
# Binders        200028.7850
# Machines       189238.6310
# Accessories    164186.7000
# Copiers        146248.0940
# Bookcases      113813.1987
# Appliances     104618.4030
# Name: Sales, dtype: float64

# %%
region_sales = df.groupby("Region")["Sales"].sum().sort_values(ascending=False)
print(region_sales)
region_sales.plot(Kind="bar", title="Sales by Region")
# Out:
# Region
# West       710219.6845
# East       669518.7260
# Central    492646.9132
# South      389151.4590
# Name: Sales, dtype: float64
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 3
#       1 region_sales = df.groupby("Region")["Sales"].sum().sort_values(ascending=False)
#       2 print(region_sales)
# ----> 3 region_sales.plot(Kind="bar", title="Sales by Region")
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
region_sales = df.groupby("Region")["Sales"].sum().sort_values(ascending=False)
print(region_sales)
# Out:
# Region
# West       710219.6845
# East       669518.7260
# Central    492646.9132
# South      389151.4590
# Name: Sales, dtype: float64

# %%
region_sales.plot(kind="bar")
plt.title("Sales by Region")
plt.show()

# %% [markdown]
# Key Findings
#
# Technology drives the highest sales; Furniture next; Office Supplies lowest.
# Phones lead all sub-categories.
# West region contributes the most revenue.
# Consumer segment dominates purchases.
# Sales vary month-to-month (seasonality present).
# (If you checked Profit) Some products generate revenue but negative profit → pricing/discount issue.

# %% [markdown]
# # Sales Data Analysis Project
#
# ## Objective
# To analyze a retail sales dataset and extract meaningful business insights using Python.

# %% [markdown]
# ## Introduction
#
# This project focuses on analyzing a retail sales dataset to understand sales performance across different categories, regions, and customer segments.
#
# The goal is to identify patterns, trends, and key factors influencing sales using data analysis and visualization techniques.

# %% [markdown]
# ## Data Cleaning
#
# - Loaded dataset using Pandas
# - Handled missing values in Postal Code column
# - Converted date columns to proper datetime format
# - Removed duplicate records
# - Ensured data consistency for analysis

# %% [markdown]
# ## Exploratory Data Analysis
#
# Performed analysis to understand:
#
# - Sales distribution across categories
# - Regional performance
# - Customer segment contribution
# - Monthly sales trends

# %% [markdown]
# ## Visualizations
#
# Created visual representations using Matplotlib and Seaborn to better understand trends and patterns in the data.

# %% [markdown]
# ## Key Insights
#
# - Technology category generates the highest sales
# - Phones are the top-performing sub-category
# - West region contributes the most revenue
# - Consumer segment dominates overall sales
# - Sales show variation across different months

# %% [markdown]
# ## Conclusion
#
# This analysis highlights key business trends and opportunities. The insights can help in improving sales strategies, optimizing product performance, and making data-driven decisions.
#
# This project also strengthened my skills in data cleaning, analysis, and visualization using Python.
